# %% [raw]
#                         Python
#                         =======
# Versions:
#     1x
#     2x = 2.7.16
#     3x = 3.7.2
#
# Python IDLE--> Integrated Development & Learning Environment
#
# Identifier Rule:
#     * a declaration should start with alphabetic either capital or smaller letter
#     * a declaration can start with underscore(_)
#     * a declaration should not start with number of symbol
#
# Python is a case sensitive language
#
# Comments:
#     * one line comment --> starts with #
#     * Multi line comment --> either by three single quotation or three double quotation
#         '''this is multiline
#             single quotation comment'''
#         """this is multiline
#             double quotation comment"""
#
# Data Literals or Data Type:
# ============================
#     1. String Literals
#         name="Jeeva"
#     2. Multiline String decclaration
#         Paragraph='''i am learning
#                     python and
#                     Data science'''
#     3. Numerical declaration
#         - Int
#         - Float
#         - Complex (j is the python imaginory variable)
#     4. Boolean
#     5. None type
#     6. Tuple
#         - Collection of different datatype
#         - connot be modified
#         - should be given inside ()
#     7. List
#         - Collection of different datatype
#         - can be modified (Mutable)
#         - should be given inside []
#         - Addressing(Indexing) in order manner
#         - Random access possible
#         - Duplicate possible
#     8. Dictionary
#         - key value pair
#         - can be modified
#         - should be given inside {}
#     9. Set
#         - Random memory
#         - cannot be modified
#         - duplicate will be removed
#         - should be inside {}
#
# Operations:
# ===========
# 7 types of operators
#     1. Arithmetic operators
#         * Addition --> A+B
#         * Seperation --> A-B
#         * Multiplication --> A*B
#         * Division --> A/B --> float output
#         * Modular --> A%B --> devision reminder output
#         * Floor division --> A//B --> 5/2=2
#         * Power --> A**B
#     2. Assignment operator (=)
#         a=5
#         a+=1 --> a=a+1
#     3. Relative operator
#         * >
#         * <
#         * <=
#         * >=
#         * !=
#         * output will always will be boolean
#     4. Logical operator
#         * And
#         * Or
#         * Not
#     5. Membership operator
#         * in
#         * output will always will be boolean
#         Ex: MyList=[1,2,3]
#             print(2 in MyList)
#     6. Identity operator
#         * is
#         * output will always will be boolean
#         Ex: print(5 is 5)
#     7. Bitwise operator
#         * AND (&)
#         * OR (|)
#         * XOR (^)
#
# Getting input from user:
# ========================
#     a=input("Enter a value: ")
#     print(a)
#
# Conditional statement:
# =======================
#     1. Simple if
#     2. if---else
#     3. if--
#             if--
#             else
#         else
#     4. if--
#         elif--
#         elif--
#         else
# Loop:
# ======
#     1. While
#     2. Do---While
#     3. For each
#
#     Loop Control:
#         *'break' will exit the loop and stop loop iteration
#         * 'continue' will exit the iteration and go to next iteration
#         * 'pass' will not affect the loop and bypass the loop
#     When loop continously executing, ctrl+c will stop the execution running
#
# Function:
# =========
# Introduction:
#
# 1. A function is a self block of code
# 2. A function can be called as section of a program that is written once and can be executed
#    whenever required in the program, thus making code reusability
# 3. A function is a subprogram that works on data and produce same output.
#
# Types of functions:
#
# There are two type of function.
# a) Built-in functions:
#       * Functions that are predefined.
#       * We have used many predefined functions in python
#
# b) user defined:
#       * Functions that are created according to the requirements.
#
#
# User defined functions:
#     procedure call is calling the funtion with this is name
#
# Funtion declaration:
#
# Ex: 1
# def myFunction():
#       print("Hi.. i am user defined function")
#
# -->we can create n number of funtion in package and can call the function n number times based on requirement.
# -->function will take the value from calling function parameters.
#     if parameter is not available, it will take the default value assigned in fucntion
#
# Returning function:
#
# #Function Declaration
# def add(a,b): #a,b - arguments
#       return a+b
#
# print(add(a=1,b=4))
#
# Module:
# =======
#
# * Modules are used to categorize python code into smaller parts.
# * A module is simply a python file, where classes, functions and variables are defined.
# * Grouping similar code into a single file makes it easy to access.
# * Module can be accessed by declaring (import ModuleName)
#
# Python module advantage:
# 1. Reusability: Module can be used in some other python code.
#                 Hence it provides the facility of reusability.
#
# Lamda function:
# ===============
#
# x=lambda a,b:a**2+b**2
#
# print(x(a=2,b=3))
#
# List:
# =====
#     1. len(MyList) --> finding the length of the list
#     2. MyList.clear() --> clear the list
#     3. MyList.append("orange")--> append a item in the list
#     4. MyList.pop() --> remove the last item of the list
#     5. MyList.count("Data") --> number of times the item available in the list
#     6. MyList.index("Data") --> item index
#     7. MyList.insert(1,"jeeva") --> insert item at the index
#     8. MyList.remove("Data") --> remove an item
#     9. MyList.reverse() --> reverse the list
#     10. x=MyList.copy() --> copy the list to another list variable
#     11. MyList.sort(reverse=True) --> sort the list items
#
# print(dir(list))
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__',
#  '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__',
#  '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__',
#  '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__',
#  '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__',
#  '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__',
#  '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear',
#  'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
#
# Tupe:
# ======
# print(dir(tuple))
#
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__',
# '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__',
# '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__',
# '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__',
# '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__',
# '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__',
# '__subclasshook__', 'count', 'index']
#
# Dictionary:
# ============
# print(dir(myDict))
#
# ['__class__', '__contains__', '__delattr__', '__delitem__',
#  '__dir__', '__doc__', '__eq__', '__format__', '__ge__',
#  '__getattribute__', '__getitem__', '__gt__', '__hash__',
#  '__init__', '__init_subclass__', '__iter__', '__le__', '__len__',
#  '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__',
#  '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__',
#  '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items',
#  'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
#
# File handling:
# ===============
# #write
#
# F=open("C:/Users/HP1/Desktop/data.txt","w")
# F.write("Writing some text")
# F.close() #Without closing the save will not work
#
# #Append
#
# F=open("C:/Users/HP1/Desktop/data.txt","a")
# F.write(" check")
# F.close()
#
# #Read
#
# F=open("C:/Users/HP1/Desktop/data.txt","r")
# data=F.read()
# print(data)
# F.close()
#
# Folder Handling:
# =================
# import os
# #create folder
#
# os.mkdir("C:/Users/HP1/Desktop/DataScience")
# #rename folder
#
#
# os.rename("C:/Users/HP1/Desktop/DS","C:/Users/HP1/Desktop/DS1")
#
# #remove folder
#
# os.rmdir("C:/Users/HP1/Desktop/DS1")
#
# #get current working directory
#
# cwd=os.getcwd()
# print(cwd)
#
# output:
# C:\Users\HP1\AppData\Local\Programs\Python\Python37
#
#
# Try-Catch:
# ============
#
# a=5
# b=0
#
# try:
#       division=a/b
#       print(division)
#
# except:
#       print("error occurred")
#
# print("good bye")
#
#
#
#
#
# Pandas Intro
# =============
# 1D or one dimentional or series
#
# 2D or two dimentional or DataFrame
#
# 3D or three dimentional or Panel
#
# (Pa)nel + (Da)ta'(s)=Pandas
#
# 1D or one dimentional or series
# ================================
# List
# Tuple
# Dictionary
# Array or ndarray - number dimentional array
# Structure:
# Index or Rows or axis=0 or major_axis
#
# Import Pandas pandas.Series(data, index, dtype, copy)
