# %% [markdown]
# # Excel calling

# %%
import pandas as pd
dataFrame=pd.read_excel("D:/Learning/Data science/testdata.xlsx",sheetname=0)
print(dataFrame)
print("size: ",dataFrame.size)
# Out:
#   FirstName    LastName   Salary
# 0     jeeva       madhu  89897.0
# 1   dhinesh  sivalingam  98988.0
# 2    ganesh       sivam   6546.0
# 3     manoj       kumar  87789.0
# 4      mani         NaN      NaN
# size:  15

# %%
import pandas as pd
dataFrame=pd.read_excel("D:/Learning/Data science/testdata.xlsx",sheetname="test")
print(dataFrame)
print("size: ",dataFrame.size)
# Out:
#   FirstName    LastName   Salary
# 0     jeeva       madhu  89897.0
# 1   dhinesh  sivalingam  98988.0
# 2    ganesh       sivam   6546.0
# 3     manoj       kumar  87789.0
# 4      mani         NaN      NaN
# size:  15

# %%
import pandas as pd
dataFrame=pd.read_excel("D:/Learning/Data science/testdata.xlsx",sheetname="test",header=2,names=["A","B","C"])
print(dataFrame)
print("size: ",dataFrame.size)
# Out:
#         A      B        C
# 0  ganesh  sivam   6546.0
# 1   manoj  kumar  87789.0
# 2    mani    NaN      NaN
# size:  9

# %% [markdown]
# # csv calling

# %%
import pandas as pd
dataFrame=pd.read_csv("D:/Learning/Data science/mobile_cleaned-1549119762886.csv",delimiter=",")
print(dataFrame)
print(dataFrame.size)
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0            250                 1.30
# 1           0         1        55   132.0            300                 1.30
# 2           0         9        55   142.0            329                 1.50
# 3           0         8        55   152.0            385                 1.30
# 4           1         1        55   234.0            385                 1.30
# 5           0        14        55   179.0            280                 1.30
# 6           1         1        56   124.0            230                 1.30
# 7           0         8        41   154.0            182                 1.00
# 8           1         8        41   214.0            182                 1.00
# 9           0         1        55   155.0            435                 1.30
# 10          0         1        55   169.0            514                 1.30
# ...

# %%
import pandas as pd
dataFrame=pd.read_csv("D:/Learning/Data science/testdata.csv",delimiter=",")
print(dataFrame)
print("size: ",dataFrame.size)
# Out:
#   FirstName    LastName   Salary
# 0     jeeva       madhu  89897.0
# 1   dhinesh  sivalingam  98988.0
# 2    ganesh       sivam   6546.0
# 3     manoj       kumar  87789.0
# 4      mani         NaN      NaN
# size:  15

# %% [markdown]
# # text calling

# %%
import pandas as pd
dataFrame=pd.read_csv("D:/Learning/Data science/testdata1.txt",delimiter=",")
print(dataFrame)
print("size: ",dataFrame.size)
# Out:
#   FirstName    LastName   Salary
# 0     jeeva       madhu  89897.0
# 1   dhinesh  sivalingam  98988.0
# 2    ganesh       sivam   6546.0
# 3     manoj       kumar  87789.0
# 4      mani         NaN      NaN
# size:  15

# %% [markdown]
# # URL csv calling
